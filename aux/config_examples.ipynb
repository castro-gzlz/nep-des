# %%
# ===================================================================
# USER CONFIGURATION – example#1
# ===================================================================

# 1) Catalogue
catalog = "NEA"

# 2) Boundaries and labels
show_boundaries        = "desert"
show_labels            = "desert"
show_mazeh_boundaries  = False

# 3) User planets
user_planets = [

    dict(
        name="TOI-849 b",
        P_days=0.76552414,
        R_Rearth=3.444,
        R_err_up=0.157,
        R_err_down=0.115,
        color="#FF99E6",
        dx_label=0.0,
        dy_label=0.0,
    ),

    dict(
        name="TOI-1853 b",
        P_days=1.2436258,
        R_Rearth=3.46,
        R_err_up=0.08,
        R_err_down=0.08,
        color="#80BFFF",
        dx_label=0.0,
        dy_label=0.0,
    ),

    dict(
        name="LTT 9779 b",
        P_days=0.7920520,
        R_Rearth=4.72,
        R_err_up=0.23,
        R_err_down=0.23,
        color="#80FFAA",
        dx_label=0.0,
        dy_label=0.0,
    ),

    dict(
        name="TOI-3071 b",
        P_days=0.7920520,
        R_Rearth=7.16,
        R_err_up=0.57,
        R_err_down=0.51,
        color="#00F5FF",
        dx_label=0.0,
        dy_label=0.0,
    ),

    dict(
        name="TOI-674 b",
        P_days=1.977143,
        R_Rearth=5.25,
        R_err_up=0.17,
        R_err_down=0.17,
        color="#FFC766",
        dx_label=0.0,
        dy_label=0.0,
    ),

    dict(
        name="K2-45 b",
        P_days=1.7292684,
        R_Rearth=6.71,
        R_err_up=0.0,
        R_err_down=0.0,
        color="#D1B3FF",
        dx_label=0.0,
        dy_label=0.0,
    ),
]

# 4) Label style
legend_or_box = "legend"

# 7) Output tag
plot_tag = "example1"

# %%
# ===================================================================
# USER CONFIGURATION – example#2
# ===================================================================

# 1) Catalogue
catalog = "Exoplanet.eu"

# 2) Boundaries and labels
show_boundaries       = "desert,ridge"
show_labels           = "desert,ridge,savanna"
show_mazeh_boundaries = False

# 3) User planets
user_planets = [
    dict(
        name="TOI-257 b",
        P_days=18.38818,
        R_Rearth=7.162539,
        R_err_up=0.145717,
        R_err_down=0.145717,
        color="dodgerblue",
        dx_label=0.0,
        dy_label=1.0,
    ),
]

# 4) Planet label mode
legend_or_box = "box"

# 7) Output tag
plot_tag = "example2"

# %%
# ===================================================================
# USER CONFIGURATION — example#3
# ===================================================================

# 1) Catalogue
catalog = "NEA"

# 2) Boundaries and labels
show_boundaries       = "desert,ridge"
show_labels           = "desert,ridge,savanna"
show_mazeh_boundaries = False

# 3) User planets (alternating M/R and rho_cgs)
user_planets = [

    # M and R
    dict(
        name="TOI-5005 b",
        P_days=6.3085044,
        R_Rearth=6.25,
        R_err_up=0.24,
        R_err_down=0.24,
        M_Mearth=32.7,
        M_err_up=5.9,
        M_err_down=5.9,
        color="#FF8080",
        dx_label=0.0,
        dy_label=0.0,
    ),

    # Density (rho_cgs)
    dict(
        name="LTT 9779 b",
        P_days=0.792052,
        R_Rearth=4.72,
        R_err_up=0.23,
        R_err_down=0.23,
        rho_cgs=1.53635,
        rho_err_up=0.22828,
        rho_err_down=0.22857,
        color="#80BFFF",
        dx_label=0.0,
        dy_label=0.0,
    ),

    # M and R
    dict(
        name="TOI-6038 A b",
        P_days=5.8267311,
        R_Rearth=6.41,
        R_err_up=0.20,
        R_err_down=0.16,
        M_Mearth=78.5,
        M_err_up=9.5,
        M_err_down=9.9,
        color="#80FFAA",
        dx_label=0.0,
        dy_label=0.0,
    ),

    # Density (rho_cgs)
    dict(
        name="NGTS-14 A b",
        P_days=3.5357173,
        R_Rearth=4.976796,
        R_err_up=0.33627,
        R_err_down=0.33627,
        rho_cgs=1.30703,
        rho_err_up=0.31505,
        rho_err_down=0.31505,
        color="#00F5FF",
        dx_label=0.0,
        dy_label=0.0,
    ),

    # M and R
    dict(
        name="Kepler-25 c",
        P_days=12.72070,
        R_Rearth=5.217,
        R_err_up=0.07,
        R_err_down=0.07,
        M_Mearth=15.2,
        M_err_up=1.6,
        M_err_down=1.6,
        color="#FFC766",
        dx_label=0.0,
        dy_label=0.0,
    ),

    # Density (rho_cgs)
    dict(
        name="TOI-421 c",
        P_days=16.067541,
        R_Rearth=5.09,
        R_err_up=0.07,
        R_err_down=0.07,
        rho_cgs=0.58914,
        rho_err_up=0.06334,
        rho_err_down=0.06334,
        color="#FFB3A6",
        dx_label=0.0,
        dy_label=0.0,
    ),

    # M and R
    dict(
        name="K2-32 b",
        P_days=8.992,
        R_Rearth=5.299,
        R_err_up=0.191,
        R_err_down=0.191,
        M_Mearth=15.0,
        M_err_up=1.8,
        M_err_down=1.7,
        color="#FF99E6",
        dx_label=0.0,
        dy_label=0.0,
    ),
]

# 4) Planet label mode
legend_or_box = "legend"

# 5) Radius band + density panel configuration
R_band_min       = 4.5
R_band_max       = 7.5
density_ymax     = 3.2
density_xlim_max = 23.0

# 6) Precision cuts (P–ρ panel only)
max_rel_err_rho_pct = 33.0  # %
include_user_planets_in_density_stats = False

# 7) Output tag
plot_tag = "example3"

# %%
# ===================================================================
# USER CONFIGURATION – example#4
# ===================================================================

# 1) Catalogue
catalog = "NEA"

# 2) Boundaries and labels
show_boundaries       = "desert"
show_labels           = "desert"
show_mazeh_boundaries = False

# 3) User planets (inline labels)
user_planets = [
    dict(
        name="TOI-849 b",
        P_days=0.76552414,
        R_Rearth=3.444,
        R_err_up=0.157,
        R_err_down=0.115,
        color="#ff66cc",
        dx_label=0.0,
        dy_label=0.4,
    ),
]

# 4) Planet label mode
legend_or_box = "box"

# 7) Output tag
plot_tag = "example4"

# %%
# ===================================================================
# USER CONFIGURATION – example#5
# ===================================================================

# 1) Catalogue
catalog = "NEA"

# 2) Boundaries and labels
show_boundaries       = "desert,ridge"
show_labels           = "desert,ridge,savanna"
show_mazeh_boundaries = True

# 3) User planets
user_planets = [

    dict(
        name="TOI-849 b",
        P_days=0.76552414,
        R_Rearth=3.444,
        R_err_up=0.157,
        R_err_down=0.115,
        color="#ff66cc",
        dx_label=0.0,
        dy_label=0.0,
    ),

    dict(
        name="TOI-1853 b",
        P_days=1.2436258,
        R_Rearth=3.46,
        R_err_up=0.08,
        R_err_down=0.08,
        color="#66e0ff",
        dx_label=0.0,
        dy_label=0.0,
    ),

    dict(
        name="TOI-3071 b",
        P_days=0.7920520,
        R_Rearth=7.16,
        R_err_up=0.57,
        R_err_down=0.51,
        color="#99ff99",
        dx_label=0.0,
        dy_label=0.0,
    ),

    dict(
        name="TOI-674 b",
        P_days=1.977143,
        R_Rearth=5.25,
        R_err_up=0.17,
        R_err_down=0.17,
        color="#ff9999",
        dx_label=0.0,
        dy_label=0.0,
    ),

    dict(
        name="K2-45 b",
        P_days=1.7292684,
        R_Rearth=6.71,
        R_err_up=0.0,
        R_err_down=0.0,
        color="#80bfff",
        dx_label=0.0,
        dy_label=0.0,
    ),
]

# 4) Display mode
legend_or_box = "legend"

# 7) Output tag
plot_tag = "example5"
