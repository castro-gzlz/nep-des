# %%
# ===================================================================
# USER CONFIGURATION – example #1
# ===================================================================

# -------------------------------------------------------------------
# 1) MAIN SETTINGS
# -------------------------------------------------------------------

# 1.1 Catalogue
catalog = "NEA"
plot_tag = "example1"

# 1.2 Boundaries / labels to show
show_boundaries = "desert"
show_labels = "desert"

# 1.4 User planets
legend_or_box = "legend"

user_planets = [
    dict(
        name="TOI-849 b",
        P_days=0.76552414,
        R_Rearth=3.444,
        R_err_up=0.157,
        R_err_down=0.115,
        color="#FF99E6",
        dx_label=0.0,
        dy_label=0.0,
    ),
    dict(
        name="TOI-1853 b",
        P_days=1.2436258,
        R_Rearth=3.46,
        R_err_up=0.08,
        R_err_down=0.08,
        color="#80BFFF",
        dx_label=0.0,
        dy_label=0.0,
    ),
    dict(
        name="LTT 9779 b",
        P_days=0.7920520,
        R_Rearth=4.72,
        R_err_up=0.23,
        R_err_down=0.23,
        color="#80FFAA",
        dx_label=0.0,
        dy_label=0.0,
    ),
    dict(
        name="TOI-3071 b",
        P_days=0.7920520,
        R_Rearth=7.16,
        R_err_up=0.57,
        R_err_down=0.51,
        color="#00F5FF",
        dx_label=0.0,
        dy_label=0.0,
    ),
    dict(
        name="TOI-674 b",
        P_days=1.977143,
        R_Rearth=5.25,
        R_err_up=0.17,
        R_err_down=0.17,
        color="#FFC766",
        dx_label=0.0,
        dy_label=0.0,
    ),
    dict(
        name="K2-45 b",
        P_days=1.7292684,
        R_Rearth=6.71,
        R_err_up=0.0,
        R_err_down=0.0,
        color="#D1B3FF",
        dx_label=0.0,
        dy_label=0.0,
    ),
]

# %%
# ===================================================================
# USER CONFIGURATION – example #2
# ===================================================================

# -------------------------------------------------------------------
# 1) MAIN SETTINGS
# -------------------------------------------------------------------

# 1.1 Catalogue
catalog = "Exoplanet.eu"
plot_tag = "example2"

# 1.2 Boundaries / labels to show
show_boundaries = "desert,ridge"
show_labels = "desert,ridge,savanna"

# 1.4 User planets
legend_or_box = "box"

user_planets = [
    dict(
        name="TOI-257 b",
        P_days=18.38818,
        R_Rearth=7.162539,
        R_err_up=0.145717,
        R_err_down=0.145717,
        color="dodgerblue",
        dx_label=0.0,
        dy_label=1.0,
    ),
]

# %%
# ===================================================================
# USER CONFIGURATION – example #3
# ===================================================================

# -------------------------------------------------------------------
# 1) MAIN SETTINGS
# -------------------------------------------------------------------

# 1.1 Catalogue
catalog = "NEA"
plot_tag = "example3"

# 1.2 Boundaries / labels to show
show_boundaries = "desert,ridge"
show_labels = "desert,ridge,savanna"

# 1.4 User planets
legend_or_box = "box"

user_planets = [
    dict(
        name="TOI-849 b",
        P_days=0.76552414,
        R_Rearth=3.444,
        R_err_up=0.157,
        R_err_down=0.115,
        color="#ff66cc",
        dx_label=0.0,
        dy_label=0.4,
    ),
]

# %%
# ===================================================================
# USER CONFIGURATION – example #4
# ===================================================================

# -------------------------------------------------------------------
# 1) MAIN SETTINGS
# -------------------------------------------------------------------

# 1.1 Catalogue
catalog = "NEA"
plot_tag = "example4"

# 1.2 Boundaries / labels to show
show_boundaries = "desert,ridge"
show_labels = "desert,ridge,savanna"

# 1.3 Additional curves / overlays
show_tidal_boundary = True
show_lidov_kozai_and_secular_chaos_scalings = False

# 1.4 User planets
legend_or_box = "legend"

user_planets = [
    dict(
        name="NGTS-14 A b",
        P_days=3.5357173,
        R_Rearth=4.976796,
        R_err_up=0.33627,
        R_err_down=0.33627,
        color="tomato",
        dx_label=0.0,
        dy_label=0.0,
    ),
    dict(
        name="TOI-6038 A b",
        P_days=5.8267311,
        R_Rearth=6.41,
        R_err_up=0.20,
        R_err_down=0.16,
        color="#80FFAA",
        dx_label=0.0,
        dy_label=0.0,
    ),
]

# %%
# ===================================================================
# USER CONFIGURATION – example #5
# ===================================================================

# -------------------------------------------------------------------
# 1) MAIN SETTINGS
# -------------------------------------------------------------------

# 1.1 Catalogue
catalog = "NEA"
NEA_TABLE = "pscomppars"
plot_tag = "example5"

# 1.2 Boundaries / labels to show
show_boundaries = "desert,ridge"
show_labels = "desert,ridge,savanna"

# 1.3 Additional curves / overlays
show_tidal_boundary = True   # plots 2 and 3

# 1.4 User planets
legend_or_box = "legend"

user_planets = [
    dict(
        name="LTT 9779 b",
        P_days=0.792052,
        R_Rearth=4.72,
        R_err_up=0.23,
        R_err_down=0.23,
        M_Mearth=29.32,
        M_err_up=0.78,
        M_err_down=0.81,
        color="#80BFFF",
        dx_label=0.0,
        dy_label=0.0,
    ),
    dict(
        name="TOI-6038 A b",
        P_days=5.8267311,
        R_Rearth=6.41,
        R_err_up=0.20,
        R_err_down=0.16,
        M_Mearth=78.5,
        M_err_up=9.5,
        M_err_down=9.9,
        color="#80FFAA",
        dx_label=0.0,
        dy_label=0.0,
    ),
    dict(
        name="TOI-421 c",
        P_days=16.067541,
        R_Rearth=5.09,
        R_err_up=0.07,
        R_err_down=0.07,
        rho_cgs=0.58914,
        rho_err_up=0.06334,
        rho_err_down=0.06334,
        color="#FFB3A6",
        dx_label=0.0,
        dy_label=0.0,
    ),
    dict(
        name="TOI-672 b",
        P_days=3.634,
        R_Rearth=5.31,
        R_err_up=0.24,
        R_err_down=0.26,
        M_Mearth=50.9,
        M_err_up=4.5,
        M_err_down=4.4,
        color="tomato",
        dx_label=0.0,
        dy_label=0.0,
    ),
]

# -------------------------------------------------------------------
# 2) DENSITY-PLOT SETTINGS
# -------------------------------------------------------------------

# 2.1 Density sample definition
R_band_min = 4.0
R_band_max = 8.5

# 2.2 Density axes / quality cuts
density_ymax = 2.6
density_xlim_max = 23.0

max_frac_err_R_pct = 10.0
max_frac_err_M_pct = 20.0

# 2.3 Density plot extras
show_density_hist = True
show_low_density_depletion = True
show_one_gcc_line = True

# 2.4 Optional density statistics
compute_density_statistics = True
include_user_planets_in_density_stats = False
